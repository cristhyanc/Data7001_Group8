# %% [markdown]
# This python code scrapes the suburb index from Australia Post website https://auspost.com.au/postcode/suburb-index/.
#
# It randomises the order of the letters in which it works, and uses a short random delay to try
# to look innocent.

# %%
from requests import Session
import re
import numpy
import time
import sys
import csv
import datetime
import random
import string

def get_letter(letter, follow_subsequent=True):
	print("doing get_letter(\"{}\").".format(letter))
	s = Session()
	headers = {"User-Agent":  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.2 Safari/605.1.15",
			   "Origin" : "https://auspost.com.au/postcode",
			   "Referer": "https://auspost.com.au/postcode",
			   "Accept-Language" : "en-au",
			   "Host" : "auspost.com.au",
			   "Accept-Encoding" : "gzip, deflate",
			   "X-Requested-With" : "XMLHttpRequest",
	"Accept": "*/*",
	"Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
	"Connection": "keep-alive",
	}

	target_url = "https://auspost.com.au/postcode/suburb-index/{}".format(letter)
	response = s.get(target_url, headers = headers)
	result_list = []
	subsequent_page_list = []

	for i in range(len(response.text.splitlines())):
		line = response.text.splitlines()[i]
		this_result_tuple = ()
		lid = re.match( r'.*class=\"pol-suburb-index-link js-pol-suburb-index-link\">(.+)</a>', line, flags=re.IGNORECASE)
		if lid:
			this_result = lid.group(1)
			result_list.append(this_result)
		lid = re.match( r'.*<a href=\"/postcode/suburb-index/({}\d)\">\d</a>'.format(letter), line, flags=re.IGNORECASE)
		if lid:
			print("Found subsequent page: {}".format(lid.group(1)))
			this_subsequent_page = lid.group(1)
			subsequent_page_list.append(this_subsequent_page)
	if follow_subsequent:
		for subsequent_page in subsequent_page_list:
			result_list.extend(get_letter(subsequent_page, False))
	return result_list

def scrape_AP_suburb_list():
	target_letter_list = list(string.ascii_lowercase)
	random.shuffle(target_letter_list)
	number_of_target_letters = len(target_letter_list)
	i = 0
	oall_result_list = []
	for this_target_letter in target_letter_list:
		i += 1
		print("Doing letter {} of {}.".format(i, number_of_target_letters))
		if (1 < i):
			delay = 1/60 * numpy.random.exponential(10, 1)[0]
			print("Delaying {} s.".format(delay))
			sys.stdout.flush()
			time.sleep(delay)
		oall_result_list.extend(get_letter(this_target_letter))
	oall_result_list.sort()
	return oall_result_list

def write_result_list_to_file(AP_suburb_list):
	with open('AP_suburb_list.csv','w') as out:
	    csv_out=csv.writer(out)
	    csv_out.writerow(['name'])
	    for item in AP_suburb_list:
	        csv_out.writerow([item])

# %%
AP_suburb_list = scrape_AP_suburb_list()
# Out:
# Doing letter 1 of 26.
# doing get_letter("t").
# Found subsequent page: t2
# Found subsequent page: t3
# Found subsequent page: t4
# Found subsequent page: t5
# doing get_letter("t2").
# doing get_letter("t3").
# doing get_letter("t4").
# doing get_letter("t5").
# Doing letter 2 of 26.
# Delaying 0.08513744738802942 s.
# doing get_letter("k").
# Found subsequent page: k2
# Found subsequent page: k3
# Found subsequent page: k4
# Found subsequent page: k5
# doing get_letter("k2").
# doing get_letter("k3").
# doing get_letter("k4").
# doing get_letter("k5").
# Doing letter 3 of 26.
# Delaying 0.13581963854453855 s.
# doing get_letter("v").
# Doing letter 4 of 26.
# Delaying 0.5939432006690641 s.
# doing get_letter("c").
# Found subsequent page: c2
# Found subsequent page: c3
# Found subsequent page: c4
# Found subsequent page: c5
# doing get_letter("c2").
# doing get_letter("c3").
# doing get_letter("c4").
# doing get_letter("c5").
# Doing letter 5 of 26.
# Delaying 0.1811288274418808 s.
# doing get_letter("i").
# Doing letter 6 of 26.
# Delaying 0.19478686862278677 s.
# doing get_letter("z").
# Doing letter 7 of 26.
# Delaying 0.2006067301078957 s.
# doing get_letter("m").
# Found subsequent page: m2
# Found subsequent page: m3
# Found subsequent page: m4
# Found subsequent page: m5
# doing get_letter("m2").
# doing get_letter("m3").
# doing get_letter("m4").
# doing get_letter("m5").
# Doing letter 8 of 26.
# Delaying 0.06101010988965446 s.
# doing get_letter("l").
# Found subsequent page: l2
# Found subsequent page: l3
# Found subsequent page: l4
# Found subsequent page: l5
# doing get_letter("l2").
# doing get_letter("l3").
# doing get_letter("l4").
# doing get_letter("l5").
# Doing letter 9 of 26.
# Delaying 0.14413029668153138 s.
# doing get_letter("q").
# Doing letter 10 of 26.
# Delaying 0.025872982628696795 s.
# doing get_letter("s").
# Found subsequent page: s2
# Found subsequent page: s3
# Found subsequent page: s4
# Found subsequent page: s5
# doing get_letter("s2").
# doing get_letter("s3").
# doing get_letter("s4").
# doing get_letter("s5").
# Doing letter 11 of 26.
# Delaying 0.11030246298243436 s.
# doing get_letter("h").
# Found subsequent page: h2
# Found subsequent page: h3
# Found subsequent page: h4
# doing get_letter("h2").
# doing get_letter("h3").
# doing get_letter("h4").
# Doing letter 12 of 26.
# Delaying 0.01074611001459977 s.
# doing get_letter("g").
# Found subsequent page: g2
# Found subsequent page: g3
# Found subsequent page: g4
# Found subsequent page: g5
# doing get_letter("g2").
# doing get_letter("g3").
# doing get_letter("g4").
# doing get_letter("g5").
# Doing letter 13 of 26.
# Delaying 0.11995757406174233 s.
# doing get_letter("b").
# Found subsequent page: b2
# Found subsequent page: b3
# Found subsequent page: b4
# Found subsequent page: b5
# doing get_letter("b2").
# doing get_letter("b3").
# doing get_letter("b4").
# doing get_letter("b5").
# Doing letter 14 of 26.
# Delaying 0.10591378699213223 s.
# doing get_letter("w").
# Found subsequent page: w2
# Found subsequent page: w3
# Found subsequent page: w4
# Found subsequent page: w5
# doing get_letter("w2").
# doing get_letter("w3").
# doing get_letter("w4").
# doing get_letter("w5").
# Doing letter 15 of 26.
# Delaying 0.08201372216564394 s.
# doing get_letter("r").
# Found subsequent page: r2
# Found subsequent page: r3
# Found subsequent page: r4
# doing get_letter("r2").
# doing get_letter("r3").
# doing get_letter("r4").
# Doing letter 16 of 26.
# Delaying 0.5886743745096994 s.
# doing get_letter("y").
# Found subsequent page: y2
# doing get_letter("y2").
# Doing letter 17 of 26.
# Delaying 0.2232522696097998 s.
# doing get_letter("p").
# Found subsequent page: p2
# Found subsequent page: p3
# Found subsequent page: p4
# Found subsequent page: p5
# doing get_letter("p2").
# doing get_letter("p3").
# doing get_letter("p4").
# doing get_letter("p5").
# Doing letter 18 of 26.
# Delaying 0.18108216465385582 s.
# doing get_letter("u").
# Doing letter 19 of 26.
# Delaying 0.25890814764722014 s.
# doing get_letter("j").
# Doing letter 20 of 26.
# Delaying 0.28657158694623514 s.
# doing get_letter("f").
# Found subsequent page: f2
# Found subsequent page: f3
# doing get_letter("f2").
# doing get_letter("f3").
# Doing letter 21 of 26.
# Delaying 0.2618186064815953 s.
# doing get_letter("d").
# Found subsequent page: d2
# Found subsequent page: d3
# Found subsequent page: d4
# doing get_letter("d2").
# doing get_letter("d3").
# doing get_letter("d4").
# Doing letter 22 of 26.
# Delaying 0.07827298424715014 s.
# doing get_letter("n").
# Found subsequent page: n2
# Found subsequent page: n3
# Found subsequent page: n4
# Found subsequent page: n5
# doing get_letter("n2").
# doing get_letter("n3").
# doing get_letter("n4").
# doing get_letter("n5").
# Doing letter 23 of 26.
# Delaying 0.28403303762242915 s.
# doing get_letter("x").
# Doing letter 24 of 26.
# Delaying 0.02522078723396061 s.
# doing get_letter("o").
# Doing letter 25 of 26.
# Delaying 0.7147497320147117 s.
# doing get_letter("a").
# Found subsequent page: a2
# Found subsequent page: a3
# doing get_letter("a2").
# doing get_letter("a3").
# Doing letter 26 of 26.
# Delaying 0.3550330049650532 s.
# doing get_letter("e").
# Found subsequent page: e2
# Found subsequent page: e3
# doing get_letter("e2").
# doing get_letter("e3").

# %%
len(AP_suburb_list)
# Out:
# 11721

# %%
AP_suburb_list
# Out:
# ['Aarons Pass',
#  'Abba River',
#  'Abbey',
#  'Abbeyard',
#  'Abbeywood',
#  'Abbotsbury',
#  'Abbotsford',
#  'Abbotsham',
#  'Abeckett Street',
#  'Abels Bay',
#  'Abercorn',
#  'Abercrombie',
#  'Abercrombie River',
#  'Aberdare',
#  'Aberdeen',
#  'Aberfeldie',
#  'Aberfeldy',
#  'Aberfoyle',
#  'Aberfoyle Park',
#  'Aberglasslyn',
#  'Abergowrie',
#  'Abermain',
#  'Abernethy',
#  'Abingdon Downs',
#  'Abington',
#  'Abminga Station',
#  'Acacia Creek',
#  'Acacia Gardens',
#  'Acacia Hills',
#  'Acacia Ridge',
#  'Acheron',
#  'Acland',
#  'Acton',
#  'Acton Park',
#  'Ada',
#  'Adaminaby',
#  'Adams Estate',
#  'Adamstown',
#  'Adamstown Heights',
#  'Adamsvale',
#  'Adare',
#  'Adavale',
#  'Addington',
#  'Adelaide',
#  'Adelaide',
#  'Adelaide',
#  'Adelaide',
#  'Adelaide Airport',
#  'Adelaide Bc',
#  'Adelaide Lead',
#  'Adelaide Park',
#  'Adelaide River',
#  'Adelong',
#  'Adjungbilly',
#  'Advancetown',
#  'Adventure Bay',
#  'Aeroglen',
#  'Afterlee',
#  'Agery',
#  'Agnes',
#  'Agnes Banks',
#  'Agnes Water',
#  'Ainslie',
#  'Aintree',
#  'Airdmillan',
#  'Airds',
#  'Aire Valley',
#  'Aireys Inlet',
#  'Airlie Beach',
#  'Airly',
#  'Airport West',
#  'Airville',
#  'Aitkenvale',
#  'Ajana',
#  'Akaroa',
#  'Akolele',
#  'Alabama Hill',
#  'Alawa',
#  'Alawoona',
#  'Albacutya',
#  'Albanvale',
#  'Albany',
#  'Albany Creek',
#  'Albany Dc',
#  'Albany Po',
#  'Albert',
#  'Albert Park',
#  'Alberta',
#  'Alberton',
#  'Alberton West',
#  'Albinia',
#  'Albion',
#  'Albion Bc',
#  'Albion Dc',
#  'Albion Park',
#  'Albion Park Rail',
#  'Albury',
#  'Alcomie',
#  'Aldavilla',
#  'Alderley',
#  'Aldershot',
#  'Aldersyde',
#  'Aldgate',
#  'Aldinga',
#  'Aldinga Beach',
#  'Aldoga',
#  'Alectown',
#  'Alexander Heights',
#  'Alexandra',
#  'Alexandra Bridge',
#  'Alexandra Headland',
#  'Alexandra Hills',
#  'Alexandria',
#  'Alford',
#  'Alfords Point',
#  'Alfred Cove',
#  'Alfredton',
#  'Alfredtown',
#  'Algester',
#  'Ali Curung',
#  'Alice',
#  'Alice Creek',
#  'Alice River',
#  'Alice Springs',
#  'Alison',
#  'Alkimos',
#  'Allambee',
#  'Allambee Reserve',
#  'Allambee South',
#  'Allambie Heights',
#  'Allan',
#  'Allandale',
#  'Allandale Station',
#  'Allanooka',
#  'Allans Flat',
#  'Allansford',
#  'Allanson',
#  'Allawah',
#  'Alleena',
#  'Allenby Gardens',
#  'Allendale',
#  'Allendale East',
#  'Allendale North',
#  'Allens Rivulet',
#  'Allenstown',
#  'Allenview',
#  'Allestree',
#  'Allgomera',
#  'Alligator Creek',
#  'Allingham',
#  'Allora',
#  'Alloway',
#  'Allworth',
#  'Allynbrook',
#  'Alma',
#  'Alma Park',
#  'Almaden',
#  'Almonds',
#  'Almurta',
#  'Alonnah',
#  'Aloomba',
#  'Alpana',
#  'Alpha',
#  'Alphington',
#  'Alpine',
#  'Alpurrurulam',
#  'Alsace',
#  'Alstonvale',
#  'Alstonville',
#  'Alton Downs',
#  'Alton Downs Station',
#  'Altona',
#  'Altona East',
#  'Altona Gate',
#  'Altona Meadows',
#  'Altona North',
#  'Alumy Creek',
#  'Alva',
#  'Alvie',
#  'Alyangula',
#  'Amamoor',
#  'Amamoor Creek',
#  'Amaroo',
#  'Amata',
#  'Ambania',
#  'Ambarvale',
#  'Amber',
#  'Ambergate',
#  'Amberley',
#  'Ambleside',
#  'Ambrose',
#  'Amby',
#  'Amelup',
#  'American Beach',
#  'American River',
#  'Amherst',
#  'Amiens',
#  'Amity',
#  'Amity Point',
#  'Amoonguna',
#  'Amor',
#  'Amosfield',
#  'Amphitheatre',
#  'Ampilatwatja',
#  'Amyton',
#  'Anabranch North',
#  'Anabranch South',
#  'Anakie',
#  'Anakie Siding',
#  'Anama',
#  'Anambah',
#  'Anangu Pitjantjatjara Yankunytjatjara',
#  'Anatye',
#  'Ancona',
#  'Andamooka',
#  'Andamooka Station',
#  'Andergrove',
#  'Anderleigh',
#  'Anderson',
#  'Ando',
#  'Andover',
#  'Andrews',
#  'Andrews Farm',
#  'Andromache',
#  'Anduramba',
#  'Anembo',
#  'Angas Plains',
#  'Angas Valley',
#  'Angaston',
#  'Angelo River',
#  'Angepena',
#  'Angle Park',
#  'Angle Vale',
#  'Angledale',
#  'Angledool',
#  'Anglers Reach',
#  'Anglers Rest',
#  'Anglesea',
#  'Angorigina',
#  'Angourie',
#  'Angurugu',
#  'Anindilyakwa',
#  'Anketell',
#  'Anmatjere',
#  'Anna Bay',
#  'Anna Creek',
#  'Annadale',
#  'Annandale',
#  'Annangrove',
#  'Annerley',
#  'Anniebrook',
#  'Annuello',
#  'Ansons Bay',
#  'Anstead',
#  'Antechamber Bay',
#  'Anthony',
#  'Antigua',
#  'Antill Ponds',
#  'Antonymyre',
#  'Antwerp',
#  'Anula',
#  'Apamurra',
#  'Apoinga',
#  'Apollo Bay',
#  'Appila',
#  'Appin',
#  'Appin South',
#  'Apple Tree Creek',
#  'Apple Tree Flat',
#  'Appleby',
#  'Applecross',
#  'Applecross North',
#  'Applethorpe',
#  'Appletree Flat',
#  'Apslawn',
#  'Apsley',
#  'Arable',
#  'Arakoon',
#  'Araluen',
#  'Aramac',
#  'Aramara',
#  'Arana Hills',
#  'Aranbanga',
#  'Aranda',
#  'Arapiles',
#  'Ararat',
#  'Aratula',
#  'Arawata',
#  'Arbouin',
#  'Arbuckle',
#  'Arcadia',
#  'Arcadia South',
#  'Arcadia Vale',
#  'Arcadia Valley',
#  'Archdale',
#  'Archdale Junction',
#  'Archer',
#  'Archer River',
#  'Archerfield',
#  'Archerfield Bc',
#  'Archerton',
#  'Archies Creek',
#  'Arckaringa',
#  'Arcoona',
#  'Arcturus',
#  'Ardath',
#  'Ardeer',
#  'Ardglen',
#  'Arding',
#  'Ardlethan',
#  'Ardmona',
#  'Ardross',
#  'Ardrossan',
#  'Areegra',
#  'Areyonga',
#  'Argalong',
#  'Argenton',
#  'Argents Hill',
#  'Argoon',
#  'Argyle',
#  'Argyll',
#  'Ariah Park',
#  'Arkaroola',
#  'Arkaroola Village',
#  'Arkell',
#  'Arkstone',
#  'Armadale',
#  'Armadale North',
#  'Armagh',
#  'Armatree',
#  'Armidale',
#  'Armidale Dc',
#  'Armidale East',
#  'Armstrong',
#  'Armstrong Beach',
#  'Armstrong Creek',
#  'Arncliffe',
#  'Arndell Park',
#  'Arno Bay',
#  'Arnold',
#  'Arnold West',
#  'Aroona',
#  'Arrawarra',
#  'Arrawarra Headland',
#  'Arriga',
#  'Arrino',
#  'Arrowsmith',
#  'Arrowsmith East',
#  'Artarmon',
#  'Arthur River',
#  'Arthurs Creek',
#  'Arthurs Lake',
#  'Arthurs Seat',
#  'Arthurton',
#  'Arthurville',
#  'Arumbera',
#  'Arumpo',
#  'Arundel',
#  'Arundel Dc',
#  'Ascot',
#  'Ascot Park',
#  'Ascot Vale',
#  'Ashbourne',
#  'Ashburton',
#  'Ashbury',
#  'Ashby',
#  'Ashby Heights',
#  'Ashby Island',
#  'Ashcroft',
#  'Ashendon',
#  'Ashfield',
#  'Ashford',
#  'Ashgrove',
#  'Ashgrove East',
#  'Ashley',
#  'Ashmont',
#  'Ashmore',
#  'Ashmore City',
#  'Ashton',
#  'Ashtonfield',
#  'Ashville',
#  'Ashwell',
#  'Ashwood',
#  'Aspendale',
#  'Aspendale Gardens',
#  'Aspley',
#  'Asquith',
#  'Athelstone',
#  'Atherton',
#  'Athlone',
#  'Athol',
#  'Athol Park',
#  'Atholwood',
#  'Atitjere',
#  'Atkinsons Dam',
#  'Attadale',
#  'Attunga',
#  'Attwood',
#  'Atwell',
#  'Aubigny',
#  'Aubin Grove',
#  'Aubrey',
#  'Auburn',
#  'Auburn South',
#  'Auburn Vale',
#  'Auchenflower',
#  'Auchmore',
#  'Augathella',
#  'Augusta',
#  'Augustine Heights',
#  'Auldana',
#  'Aurukun',
#  'Austinmer',
#  'Austins Ferry',
#  'Austinville',
#  'Austral',
#  'Austral Eden',
#  'Australia Fair',
#  'Australia Plains',
#  'Australia Square',
#  'Australian Defence Forces',
#  'Australian National University',
#  'Australind',
#  'Avalon',
#  'Avalon Beach',
#  'Aveley',
#  'Avenel',
#  'Avenell Heights',
#  'Avenue Range',
#  'Avisford',
#  'Avoca',
#  'Avoca Beach',
#  'Avoca Dell',
#  'Avoca Vale',
#  'Avon',
#  'Avon Plains',
#  'Avon Valley National Park',
#  'Avondale',
#  'Avondale Heights',
#  'Avonmore',
#  'Avonside',
#  'Avonsleigh',
#  'Awaba',
#  'Axe Creek',
#  'Axedale',
#  'Ayers Range South',
#  'Aylmerton',
#  'Ayr',
#  'Ayrford',
#  'Ayton',
#  'Baan Baa',
#  'Baandee',
#  'Babakin',
#  'Babbage Island',
#  'Babinda',
#  'Babyl Creek',
#  'Bacchus Marsh',
#  'Back Creek',
#  'Back Forest',
#  'Back Plains',
#  'Back Valley',
#  'Backmede',
#  'Backwater',
#  'Backy Point',
#  'Baddaginnie',
#  'Baden',
#  'Badgebup',
#  'Badger Creek',
#  'Badger Head',
#  'Badgerin Rock',
#  'Badgerys Creek',
#  'Badgin',
#  'Badgingarra',
#  'Badja',
#  'Badjaling',
#  'Badu Island',
#  'Bael Bael',
#  'Baerami',
#  'Baerami Creek',
#  'Baffle Creek',
#  'Baffle West',
#  'Bagdad',
#  'Bagnoo',
#  'Bago',
#  'Bagot Well',
#  'Bagotville',
#  'Bagshot',
#  'Bagshot North',
#  'Bahgallah',
#  'Bahrs Scrub',
#  'Bailieston',
#  'Bailup',
#  'Baines',
#  'Baird Bay',
#  'Bairnsdale',
#  'Bajool',
#  'Bakara',
#  'Bakara Well',
#  'Bakers Beach',
#  'Bakers Bend',
#  'Bakers Creek',
#  'Bakers Hill',
#  'Bakers Swamp',
#  'Bakery Hill',
#  'Bakewell',
#  'Baking Board',
#  'Balaclava',
#  'Balah',
#  'Balaklava',
#  'Balala',
#  'Balbarrup',
#  'Balberra',
#  'Balcatta',
#  'Balcolyn',
#  'Balcomba',
#  'Bald Blair',
#  'Bald Hills',
#  'Bald Knob',
#  'Bald Nob',
#  'Bald Ridge',
#  'Baldersleigh',
#  'Baldina',
#  'Baldivis',
#  'Baldry',
#  'Balfes Creek',
#  'Balfours Peak',
#  'Balga',
#  'Balgal Beach',
#  'Balgowan',
#  'Balgowlah',
#  'Balgowlah Heights',
#  'Balgownie',
#  'Balhannah',
#  'Balickera',
#  'Balingup',
#  'Balintore',
#  'Balkuling',
#  'Ball Bay',
#  'Balla Balla',
#  'Balladong',
#  'Balladonia',
#  'Balladoran',
#  'Ballajura',
#  'Ballalaba',
#  'Ballan',
#  'Ballandean',
#  'Ballangeich',
#  'Ballapur',
#  'Ballarat',
#  'Ballarat Central',
#  'Ballarat East',
#  'Ballarat Mc',
#  'Ballarat North',
#  'Ballarat West',
#  'Ballard',
#  'Ballaroo',
#  'Ballast Head',
#  'Ballaying',
#  'Balldale',
#  'Ballendella',
#  'Ballengarra',
#  'Balliang',
#  'Balliang East',
#  'Ballidu',
#  'Ballimore',
#  'Ballina',
#  'Ballina Dc',
#  'Ballogie',
#  'Bally Bally',
#  'Ballyroe',
#  'Ballyrogan',
#  'Balmain',
#  'Balmain East',
#  'Balmattum',
#  'Balmoral',
#  'Balmoral Ridge',
#  'Balnagowan',
#  'Balnarring',
#  'Balnarring Beach',
#  'Balook',
#  'Balranald',
#  'Balwyn',
#  'Balwyn East',
#  'Balwyn North',
#  'Bamaga',
#  'Bamarang',
#  'Bamawm',
#  'Bamawm Extension',
#  'Bambaroo',
#  'Bamboo',
#  'Bamboo Creek',
#  'Bambra',
#  'Bambun',
#  'Bamganie',
#  'Ban Ban',
#  'Ban Ban Springs',
#  'Banana',
#  'Banca',
#  'Bancroft',
#  'Banda Banda',
#  'Bandiana',
#  'Bandiana Milpo',
#  'Bandon Grove',
#  'Bandy Creek',
#  'Bandya',
#  'Bangadang',
#  'Bangalee',
#  'Bangalow',
#  'Bangerang',
#  'Bangham',
#  'Bangheet',
#  'Bangholme',
#  'Bango',
#  'Bangor',
#  'Banjup',
#  'Banks',
#  'Banks Creek',
#  'Banks Pocket',
#  'Banksia',
#  'Banksia Beach',
#  'Banksia Grove',
#  'Banksia Park',
#  'Banksia Peninsula',
#  'Banksiadale',
#  'Banksmeadow',
#  'Bankstown',
#  'Bankstown Aerodrome',
#  'Bankstown North',
#  'Bankstown Square',
#  'Bannaby',
#  'Bannerton',
#  'Bannister',
#  'Bannockburn',
#  'Banoon',
#  'Banora Point',
#  'Banya',
#  'Banyabba',
#  'Banyan',
#  'Banyena',
#  'Banyo',
#  'Banyule',
#  'Bapaume',
#  'Bar Beach',
#  'Bar Point',
#  'Bara',
#  'Barabba',
#  'Baradine',
#  'Baralaba',
#  'Barambah',
#  'Baranduda',
#  'Barangaroo',
#  'Baratta',
#  'Barbalin',
#  'Barberton',
#  'Barcaldine',
#  'Barcoongere',
#  'Barden Ridge',
#  'Bardia',
#  'Bardon',
#  'Bardwell Park',
#  'Bardwell Valley',
#  'Baree',
#  'Bareena',
#  'Barellan',
#  'Barellan Point',
#  'Barfold',
#  'Bargara',
#  'Bargo',
#  'Barham',
#  'Barigan',
#  'Baringa',
#  'Baringhup',
#  'Baringhup West',
#  'Barinia',
#  'Barjarg',
#  'Barker Creek Flat',
#  'Barkers Creek',
#  'Barkers Vale',
#  'Barkly',
#  'Barkstead',
#  'Barlil',
#  'Barlows Hill',
#  'Barlyne',
#  'Barmah',
#  'Barmaryee',
#  'Barmedman',
#  'Barmera',
#  'Barmoya',
#  'Barna',
#  'Barnadown',
#  'Barnard',
#  'Barnawartha',
#  'Barnawartha North',
#  'Barndioota',
#  'Barnes Bay',
#  'Barney Point',
#  'Barney View',
#  'Barneys Reef',
#  'Barnsley',
#  'Baromi',
#  'Barongarook',
#  'Barongarook West',
#  'Barooga',
#  'Baroota',
#  'Barossa Goldfields',
#  'Barraba',
#  'Barrabool',
#  'Barrabup',
#  'Barrack Heights',
#  'Barrack Point',
#  'Barraganyatti',
#  'Barragga Bay',
#  'Barragup',
#  'Barrakee',
#  'Barramornie',
#  'Barramunga',
#  'Barraport',
#  'Barraport West',
#  'Barratta',
#  'Barren Grounds',
#  'Barrengarry',
#  'Barretta',
#  'Barretts Creek',
#  'Barrine',
#  'Barringella',
#  'Barringha',
#  'Barrington',
#  'Barrington Tops',
#  'Barringun',
#  'Barron',
#  'Barron Gorge',
#  'Barrow Creek',
#  'Barrow Island',
#  'Barry',
#  'Barrys Reef',
#  'Bartle Frere',
#  'Barton',
#  'Barunah Park',
#  'Barunah Plains',
#  'Barunga',
#  'Barunga Gap',
#  'Barwang',
#  'Barwidgee',
#  'Barwidgi',
#  'Barwite',
#  'Barwon',
#  'Barwon Downs',
#  'Barwon Heads',
#  'Baryulgil',
#  'Basalt',
#  'Basilisk',
#  'Basin Pocket',
#  'Basin View',
#  'Baskerville',
#  'Basket Range',
#  'Bass',
#  'Bass Hill',
#  'Bassendean',
#  'Bassendean Dc',
#  'Batar Creek',
#  'Batchelor',
#  'Bateau Bay',
#  'Batehaven',
#  'Bateman',
#  'Batemans Bay',
#  'Batesford',
#  'Bathampton',
#  'Bathumi',
#  'Bathurst',
#  'Bathurst Island',
#  'Bathurst West',
#  'Batlow',
#  'Batman',
#  'Battery Hill',
#  'Battery Point',
#  'Baudin',
#  'Baudin Beach',
#  'Bauhinia',
#  'Baulkham Hills',
#  'Bauple',
#  'Bauple Forest',
#  'Baw Baw',
#  'Baw Baw Village',
#  'Bawley Point',
#  'Baxter',
#  'Baxters Ridge',
#  'Bay Of Shoals',
#  'Bay Village',
#  'Bayindeen',
#  'Bayles',
#  'Baynton',
#  'Baynton East',
#  'Bayonet Head',
#  'Bayrick',
#  'Bayswater',
#  'Bayswater North',
#  'Bayview',
#  'Bayview Heights',
#  'Beach Holm',
#  'Beachlands',
#  'Beachmere',
#  'Beachport',
#  'Beacon',
#  'Beacon Hill',
#  'Beaconsfield',
#  'Beaconsfield Upper',
#  'Beadell',
#  'Bealiba',
#  'Bean Creek',
#  'Bearbong',
#  'Beard',
#  'Bearii',
#  'Bears Lagoon',
#  'Beatrice',
#  'Beatty',
#  'Beauchamp',
#  'Beaudesert',
#  'Beaufort',
#  'Beaufort River',
#  'Beaumaris',
#  'Beaumont',
#  'Beaumont Hills',
#  'Beaumonts',
#  'Beauty Point',
#  'Beaver Rock',
#  'Beazleys Bridge',
#  'Beckenham',
#  'Beckom',
#  'Bective',
#  'Bectric',
#  'Bedford',
#  'Bedford Park',
#  'Bedford Road',
#  'Bedfordale',
#  'Bedgerabong',
#  'Bedourie',
#  'Beeac',
#  'Beebo',
#  'Beech Forest',
#  'Beechboro',
#  'Beecher',
#  'Beechford',
#  'Beechina',
#  'Beechmont',
#  'Beechwood',
#  'Beechworth',
#  'Beecroft',
#  'Beecroft Peninsula',
#  'Beedelup',
#  'Beela',
#  'Beelbangera',
#  'Beelbi Creek',
#  'Beelerup',
#  'Beeliar',
#  'Beemunnel',
#  'Beenaam Valley',
#  'Beenak',
#  'Beenleigh',
#  'Beenong',
#  'Beerburrum',
#  'Beermullah',
#  'Beeron',
#  'Beerwah',
#  'Bees Creek',
#  'Beetaloo Valley',
#  'Bega',
#  'Beggan Beggan',
#  'Begonia',
#  'Beilba',
#  'Bejoording',
#  'Belair',
#  'Belalie East',
#  'Belalie North',
#  'Belanglo',
#  'Belbora',
#  'Belcong',
#  'Belconnen',
#  'Belconnen Dc',
#  'Beldon',
#  'Belfield',
#  'Belford',
#  'Belfrayden',
#  'Belgian Gardens',
#  'Belgrave',
#  'Belgrave Heights',
#  'Belgrave South',
#  'Belgravia',
#  'Belhus',
#  'Belimbla Park',
#  'Belivah',
#  'Bell',
#  'Bell Bay',
#  'Bell Park',
#  'Bell Post Hill',
#  'Bella Creek',
#  'Bella Vista',
#  'Bellamack',
#  'Bellambi',
#  'Bellangry',
#  'Bellara',
#  'Bellarine',
#  'Bellata',
#  'Bellawongarah',
#  'Bellbird',
#  'Bellbird Creek',
#  'Bellbird Heights',
#  'Bellbird Park',
#  'Bellbowrie',
#  'Bellbrae',
#  'Bellbridge',
#  'Bellbrook',
#  'Bellellen',
#  'Bellenden Ker',
#  'Bellerive',
#  'Bellevue',
#  'Bellevue Heights',
#  'Bellevue Hill',
#  'Bellfield',
#  'Belli Park',
#  'Bellimbopinni',
#  'Bellingen',
#  'Bellingham',
#  'Bellmere',
#  'Bellmount Forest',
#  'Bells Beach',
#  'Bells Bridge',
#  'Bells Creek',
#  'Bellthorpe',
#  'Belltrees',
#  'Belmont',
#  'Belmont North',
#  'Belmont South',
#  'Belmore',
#  'Belmore River',
#  'Belmunda',
#  'Beloka',
#  'Belowra',
#  'Belrose',
#  'Belrose West',
#  'Beltana',
#  'Beltana Station',
#  'Belton',
#  'Belvedere',
#  'Belvidere',
#  'Belyando',
#  'Belyuen',
#  'Bemboka',
#  'Bemerside',
#  'Bemm River',
#  'Ben Bullen',
#  'Ben Lomond',
#  'Bena',
#  'Benair',
#  'Benalla',
#  'Benambra',
#  'Benandarah',
#  'Benaraby',
#  'Benarkin',
#  'Benarkin North',
#  'Benayeo',
#  'Benbournie',
#  'Bencubbin',
#  'Bend Of Islands',
#  'Benda',
#  'Bendalong',
#  'Bendemeer',
#  'Bendick Murrell',
#  'Bendigo',
#  'Bendigo Dc',
#  'Bendigo Forward',
#  'Bendigo South',
#  'Bendoc',
#  'Bendolba',
#  'Bendoura',
#  'Benerembah',
#  'Bengalla',
#  'Benger',
#  'Bengworden',
#  'Benholme',
#  'Benjaberring',
#  'Benjeroop',
#  'Benjinup',
#  'Benloch',
#  'Bennett Springs',
#  'Bennetts Green',
#  'Bennettswood',
#  'Bennison',
#  'Benobble',
#  'Benolong',
#  'Benowa',
#  'Bensville',
#  'Bentleigh',
#  'Bentleigh East',
#  'Bentley',
#  'Bentley Dc',
#  'Bentley Park',
#  'Bentley South',
#  'Benwerrin',
#  'Berajondo',
#  'Berala',
#  ...]

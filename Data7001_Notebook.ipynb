# %%
# Data from Queensland Government capital works building projects
# https://www.data.qld.gov.au/dataset/b518dada-3d2a-4d85-bd2c-febe197863c7/resource/410fb21f-8c5a-43a1-8b57-a74a3329d1d0/download/ops-open-data.csv
#install.packages("sf")
#install.packages("readr")
library(readr)
library(sf)

# %%
projects <- read.csv("https://www.data.qld.gov.au/dataset/b518dada-3d2a-4d85-bd2c-febe197863c7/resource/410fb21f-8c5a-43a1-8b57-a74a3329d1d0/download/ops-open-data.csv")
population <- read.csv("https://raw.githubusercontent.com/cristhyanc/Data7001_Group8/master/Data/estimated-resident-population-lga-qld-1991-2019p.csv")

# %%
nrow(projects)
# Out:
# [1] 204
#     ï..Project.Title
# 1   Mango Hill and Morayfield, Mango Hill State School & Morayfield State High School, Pricipal Consultant
# 2   Brisbane, Cultural Precinct, South Brisbane, Queensland Museum: Refurbishment / Renovation / Repairs, General Building, Design and construction works
# 3   Brisbane, Judith Wright Centre of Contemporary Arts, JWCoCA Refurbishment: Refurbishment / Renovation / Repairs, General Building
# 4   Lee Street, Caboolture, Caboolture State High School, Administration Refurb: New Construction Work / Addition, General Building
# 5   Moranbah State High School, Moranbah State High School, New multi-purpose hall: New Construction Work / Addition, General Building
# 6   Goodna, Goodna Special School, New Building - 8 Senior GLA/Kitchen: New Construction Work / Addition, General Building
# 7   Brisbane, Vulture Street, Woolloongabba, The Gabba: Refurbishment / Renovation / Repairs, Non-Residential Interior Refurbishment and Fitout
# ...

# %%
#Electoral Boundaries
boundaries <- st_read("https://raw.githubusercontent.com/cristhyanc/Data7001_Group8/master/Data/Boundaries/doc.kml")
plot(boundaries[1])
